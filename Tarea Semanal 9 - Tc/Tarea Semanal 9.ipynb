# %% [markdown]
# <h1>Tarea semanal 10</h1>
#
# <h3> Consignas </h3>
#
# ![image.png](attachment:b82173e3-9a2d-4b68-8912-316ee399613a.png)
#
# ![image.png](attachment:6a4d175b-d465-4da9-a783-f501e4dc744e.png)
#
# <h3> Resolucion de las consignas</h3>
#
# Se adjunta el desarrollo hecho a mano:
#
# <object data="Desarrollo.pdf" type="application/pdf" width="100%" height="800px">
#   <p>El archivo PDF no se puede mostrar. <a href="Desarrollo.pdf">Haz clic aquí para descargarlo.</a></p>
# </object>

# %% [markdown]
# <h2>Simulaciones</h2>
#
# Ejercicio 1
#
# A continuacion se simularon la impedancia de entrada de todos los metodos para comprobar que el resultado sea concordante.
#
# Metodo foster serie
#
# ![image.png](attachment:1891ca54-97ac-4ef3-bf0b-a94dbb4bda25.png)
#
# Metodo foster paralelo
#
# ![image.png](attachment:6bbe4572-10b4-4ee9-a842-acd0d1636c65.png)
#
# Metodo Cauer 1
#
# ![image.png](attachment:1fbe9f5f-ed7b-434c-bd3f-46d2eceb1804.png)
#
# Metodo Cauer 2
#
# ![image.png](attachment:23821459-2df4-4c17-b5f2-c01d32022ecd.png)
#
# Las simulaciones dieron los siguientes resultados:
#
# ![image.png](attachment:92ae0a48-b24f-4aad-8b35-40dae34fccd3.png)
#
# En donde se puede observar que todas las graficas coinciden como es de esperar.

# %% [markdown]
# Ejercicio 2:
#
# Si analizamos el circuito obtenido:
#
# ![image.png](attachment:d00d1dce-00ee-4719-8d2c-04cd12bd09a4.png)
#
# y vemos como es su admitancia de entrada:
#
# ![image.png](attachment:a4068fb7-6953-428d-bb1d-09fe21044a81.png)
#
# Podemos observar los dos polos y los dos ceros de la Y($) original.
# En este caso en la grafica estos polos dieron para un f de:
#
# 0.225Hz - 0.355Hz
#
# y los ceros en
#
# 0Hz -  0.243Hz
#
# que si los convertimos a omegas obtenemos:
# POLOS:
# 1,413 rad/s => sqrt(2)
# 2,23 rad/s => sqrt(5)
# CEROS:
# 1,527 rad/s => sqrt(7/3)
# 0 rad/s
#
# De modo que se verifica la funcion exitacion.
#
# Por otro lado si cortocircuitamos el capacitor y medimos la corriente de la rama LC izquierda debemos encontrarnos con una singularidad debido a la resonancia.
# (pico de corriente debido a la impedancia nula de la rama)
#
# ![image.png](attachment:d48790f2-83ea-4968-95a6-e0da81867d83.png)
#
# ![image.png](attachment:f9919178-fa3a-46e0-869b-3f121f23fba1.png)
#
# De forma que se comprueba que para W=1 esta rama entra en resonancia.
